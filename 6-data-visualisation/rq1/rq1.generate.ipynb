# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ## Nested Donut Chart - RQ1.1 Analysis

# %%
# Create output directory if it doesn't exist
output_dir = 'output'
os.makedirs(output_dir, exist_ok=True)

# Combined nested donut chart showing all three parameters
print("Creating combined nested donut chart for RQ1.1...")

# Prepare data for nested donut
# Inner ring: three main categories
inner_labels = ['Lifecycle Stage\nEnergy Awareness', 'Energy Integration\nPoint', 'Integration\nApproach']
inner_sizes = [38, 29, 52]  # Total counts for each category
inner_colors = ['#3182bd', '#fd8d3c', '#74c476']

# Outer ring: Items with >=3 occurrences + Other (simplified for academic paper)
outer_labels = (
    # LifecycleStageEnergyAwareness (3 items >= 5 + other)
    ['Runtime', 'Deployment', 'Design', 'Other (2 items)'] +
    # EnergyIntegrationPoint (3 items >= 3 + other)
    ['Runtime', 'Design', 'Deployment', 'Other (3 items)'] +
    # IntegrationApproach (6 items >= 3 + other)
    ['RT Monitoring', 'RT Adaptation', 'RT Scheduling', 'RT Power Mgmt',
     'RT Deploy Mgmt', 'QoS Control', 'Other (6 items)']
)

outer_sizes = (
    # LifecycleStageEnergyAwareness: 3 items >= 5, other = 2 items (1×2 + 1×1)
    [21, 9, 5, 3] +
    # EnergyIntegrationPoint: 3 items >= 3, other = 3 items (3×1)
    [19, 4, 3, 3] +
    # IntegrationApproach: 6 items >= 3, other = 6 items (2×2 + 4×1)
    [18, 8, 6, 5, 4, 3, 8]
)

# Colors for outer ring - gradient within each category
outer_colors = (
    # LifecycleStageEnergyAwareness - blue gradient (4 colors)
    ['#08519c', '#2171b5', '#4292c6', '#e0e0e0'] +
    # EnergyIntegrationPoint - orange/red gradient (4 colors)
    ['#d94801', '#f16913', '#fd8d3c', '#e0e0e0'] +
    # IntegrationApproach - green gradient (7 colors)
    ['#006d2c', '#238b45', '#41ab5d', '#74c476', '#a1d99b', '#c7e9c0', '#e0e0e0']
)


def is_dark_color(rgba, threshold=0.5):
    r, g, b, _ = rgba
    luminance = 0.299 * r + 0.587 * g + 0.114 * b
    return luminance < threshold


# Create figure
fig, ax = plt.subplots(figsize=(12, 10))

# Create labels - hide labels for items < 2% to avoid overlap
total_items = sum(outer_sizes)
display_labels = [label if (size / total_items) * 100 >= 2 else '' for label, size in zip(outer_labels, outer_sizes)]

# Plot outer ring (subcategories)
wedges_outer, texts_outer, autotexts_outer = ax.pie(
    outer_sizes,
    labels=display_labels,
    autopct=lambda pct: f'{pct:.0f}%' if pct >= 2 else '',
    radius=1.3,
    colors=outer_colors,
    wedgeprops={'width': 0.4, 'edgecolor': 'white', 'linewidth': 2},
    textprops={'fontsize': 14, 'fontweight': 'bold'},
    pctdistance=0.85,
    labeldistance=1.15,
    startangle=90
)

# Make percentage text white on dark wedges, black otherwise
for wedge, autotext in zip(wedges_outer, autotexts_outer):
    if autotext.get_text().strip():
        autotext.set_color('white' if is_dark_color(wedge.get_facecolor()) else 'black')
        autotext.set_fontweight('bold')

# Plot inner ring (main categories)
wedges_inner, texts_inner = ax.pie(
    inner_sizes,
    labels=inner_labels,
    radius=0.9,
    colors=inner_colors,
    wedgeprops={'width': 0.5, 'edgecolor': 'white', 'linewidth': 3},
    textprops={'fontsize': 15, 'fontweight': 'bold'},
    labeldistance=0.4,
    startangle=90
)

# Nudge only "Energy Integration Point" right and down to avoid overlap
from matplotlib.transforms import ScaledTranslation
energy_label = texts_inner[1]
energy_label.set_transform(
    energy_label.get_transform() + ScaledTranslation(8 / fig.dpi, -50 / fig.dpi, fig.dpi_scale_trans)
)

ax.axis('equal')

plt.tight_layout()

# Save the combined nested chart
nested_file_path = os.path.join(output_dir, 'rq1.1_nested_combined.pdf')
fig.savefig(nested_file_path, dpi=300, bbox_inches='tight')
plt.show()
plt.close(fig)

print(f"✓ Combined nested donut saved to: {nested_file_path}")
print(f"\nInner ring totals:")
print(f"  Lifecycle Stage Energy Awareness: {inner_sizes[0]} items")
print(f"  Energy Integration Point: {inner_sizes[1]} items")
print(f"  Integration Approach: {inner_sizes[2]} items")

# Output data in copy-pasteable format
print("\n" + "="*80)
print("NESTED DONUT CHART DATA - Copy/Paste Format")
print("="*80)
print("\nINNER RING (Main Categories):")
print("-" * 40)
for label, size in zip(inner_labels, inner_sizes):
    print(f"  {label.replace(chr(10), ' ')}: {size} items")

print("\n\nOUTER RING (Subcategories by Main Category):")
print("-" * 40)

print("\n1. LIFECYCLE STAGE ENERGY AWARENESS (38 items total - Items ≥5 + Other):")
ls_labels = ['Runtime', 'Deployment', 'Design', 'Other (Development(2), Maintenance(1))']
ls_sizes = [21, 9, 5, 3]
for label, size in zip(ls_labels, ls_sizes):
    pct = (size / 38) * 100
    print(f"   - {label}: {size} ({pct:.2f}%)")

print("\n2. ENERGY INTEGRATION POINT (29 items total - Items ≥3 + Other):")
ei_labels = ['Runtime', 'Design', 'Deployment',
             'Other (Analysis(1), Configuration(1), Development(1))']
ei_sizes = [19, 4, 3, 3]
for label, size in zip(ei_labels, ei_sizes):
    pct = (size / 29) * 100
    print(f"   - {label}: {size} ({pct:.2f}%)")

print("\n3. INTEGRATION APPROACH (52 items total - Items ≥3 + Other):")
ia_labels = ['Runtime Monitoring', 'Runtime Adaptation', 'Runtime Scheduling',
             'Runtime Power Management', 'Runtime Deployment Management', 'QoS-Driven Control',
             'Other (Metadata Integ(2), RT Autoscaling(2), Brownout(1), Design Analysis(1), Design Constraints(1), Placement Opt(1))']
ia_sizes = [18, 8, 6, 5, 4, 3, 8]
for label, size in zip(ia_labels, ia_sizes):
    pct = (size / 52) * 100
    print(f"   - {label}: {size} ({pct:.2f}%)")

print("\n" + "="*80)
# Out:
# Creating combined nested donut chart for RQ1.1...
# ✓ Combined nested donut saved to: output/rq1.1_nested_combined.pdf
#
# Inner ring totals:
#   Lifecycle Stage Energy Awareness: 38 items
#   Energy Integration Point: 29 items
#   Integration Approach: 52 items
#
# ...
# NESTED DONUT CHART DATA - Copy/Paste Format
# ...
#
# INNER RING (Main Categories):
# ----------------------------------------
#   Lifecycle Stage Energy Awareness: 38 items
#   Energy Integration Point: 29 items
#   Integration Approach: 52 items
#
#
# OUTER RING (Subcategories by Main Category):
# ----------------------------------------
#
# 1. LIFECYCLE STAGE ENERGY AWARENESS (38 items total - Items ≥5 + Other):
#    - Runtime: 21 (55.26%)
#    - Deployment: 9 (23.68%)
#    - Design: 5 (13.16%)
#    - Other (Development(2), Maintenance(1)): 3 (7.89%)
#
# 2. ENERGY INTEGRATION POINT (29 items total - Items ≥3 + Other):
#    - Runtime: 19 (65.52%)
#    - Design: 4 (13.79%)
#    - Deployment: 3 (10.34%)
# ...

# %% [markdown]
# ## RQ1.1
# ```values
# RQ1.1.P1	LifecycleStage	Represents the stages of the software lifecycle where energy efficiency is considered.	Runtime	21	55.26%
# 			Deployment	9	23.68%
# 			Design	5	13.16%
# 			Development	2	5.26%
# 			Maintenance	1	2.63%
# 			Total	38
# RQ1.1.P2	EnergyAwarenessStage	Describes how energy efficiency is addressed at each stage: eplicitly, implicitly, or post deployment	Runtime	19	65.52%
# 			Design	4	13.79%
# 			Deployment	3	10.34%
# 			Analysis	1	3.45%
# 			Configuration	1	3.45%
# 			Development	1	3.45%
# 			Total	29
# RQ1.1.P3	IntegrationApproach	Indicates the method used to integrate energy effieiency considerations into the system	RuntimeMonitoring	18	34.62%
# 			RuntimeAdaptation	8	15.38%
# 			RuntimeScheduling	6	11.54%
# 			RuntimePowerManagement	5	9.62%
# 			RuntimeDeploymentManagement	4	7.69%
# 			QoSDrivenControl	3	5.77%
# 			MetadataDrivenIntegration	2	3.85%
# 			RuntimeAutoscaling	2	3.85%
# 			Brownout	1	1.92%
# 			DesignTimeAnalysis	1	1.92%
# 			DesignTimeConstraints	1	1.92%
# 			PlacementOptimization	1	1.92%
# 			Total	52
# ```

# %% [markdown]
# ## Sankey Diagram - RQ1.1

# %%
import plotly.graph_objects as go

# Define nodes
nodes = [
    # LifecycleStage nodes (0-4)
    "Runtime", "Deployment", "Design", "Development", "Maintenance",
    # EnergyAwarenessStage nodes (5-10)
    "Runtime (EA)", "Design (EA)", "Deployment (EA)", "Analysis", "Configuration", "Development (EA)",
    # IntegrationApproach nodes (11-22)
    "RuntimeMonitoring", "RuntimeAdaptation", "RuntimeScheduling", "RuntimePowerManagement",
    "RuntimeDeploymentManagement", "QoSDrivenControl", "MetadataDrivenIntegration",
    "RuntimeAutoscaling", "Brownout", "DesignTimeAnalysis", "DesignTimeConstraints",
    "PlacementOptimization"
]

# Define links (source, target, value)
# LifecycleStage -> EnergyAwarenessStage
# Runtime (0) flows to Runtime (EA) (5)
# Design (2) flows to Design (EA) (6)
# Deployment (1) flows to Deployment (EA) (7)
# Development (3) flows to Development (EA) (10)

links = [
    # LifecycleStage to EnergyAwarenessStage
    (0, 5, 19),  # Runtime -> Runtime (EA)
    (2, 6, 4),   # Design -> Design (EA)
    (1, 7, 3),   # Deployment -> Deployment (EA)
    (3, 10, 1),  # Development -> Development (EA)
    
    # EnergyAwarenessStage to IntegrationApproach
    # Runtime (EA) to runtime approaches
    (5, 11, 18),  # Runtime (EA) -> RuntimeMonitoring
    (5, 12, 8),   # Runtime (EA) -> RuntimeAdaptation
    (5, 13, 6),   # Runtime (EA) -> RuntimeScheduling
    (5, 14, 5),   # Runtime (EA) -> RuntimePowerManagement
    (5, 15, 4),   # Runtime (EA) -> RuntimeDeploymentManagement
    (5, 16, 3),   # Runtime (EA) -> QoSDrivenControl
    (5, 17, 2),   # Runtime (EA) -> MetadataDrivenIntegration
    (5, 18, 2),   # Runtime (EA) -> RuntimeAutoscaling
    (5, 19, 1),   # Runtime (EA) -> Brownout
    
    # Design (EA) to design-time approaches
    (6, 20, 1),   # Design (EA) -> DesignTimeAnalysis
    (6, 21, 1),   # Design (EA) -> DesignTimeConstraints
    
    # Deployment (EA) to deployment approaches
    (7, 22, 1),   # Deployment (EA) -> PlacementOptimization
]

# Create the Sankey diagram
fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=nodes,
        color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd",  # LifecycleStage
               "#aec7e8", "#c7e9c0", "#ffbb78", "#98df8a", "#c5b0d5", "#bcbd22",  # EnergyAwarenessStage
               "#17becf", "#9edae5", "#dbdb8d", "#c49c94", "#f7b6d2", "#c7c7c7",  # IntegrationApproach
               "#bcbd22", "#e377c2", "#7f7f7f", "#8c564b", "#ff9896", "#17becf"]
    ),
    link=dict(
        source=[link[0] for link in links],
        target=[link[1] for link in links],
        value=[link[2] for link in links]
    )
)])

fig.update_layout(
    title="Energy Efficiency Integration: Lifecycle Stages to Integration Approaches",
    font_size=12,
    height=800,
    width=1200
)

fig.show()

# %% [markdown]
# ## Sankey Diagram - RQ1.1 (Version 2 - Runtime Focus)

# %%
import plotly.graph_objects as go

# Define nodes - Runtime approaches first, then Design-time approaches
nodes = [
    # Source node
    "Runtime",
    # Runtime Integration Approaches (1-9)
    "RuntimeMonitoring", "RuntimeAdaptation", "RuntimeScheduling", "RuntimePowerManagement",
    "RuntimeDeploymentManagement", "QoSDrivenControl", "MetadataDrivenIntegration",
    "RuntimeAutoscaling", "Brownout",
    # Design-time Integration Approaches (10-12)
    "DesignTimeAnalysis", "DesignTimeConstraints", "PlacementOptimization"
]

# Define links with color coding
runtime_links = [
    (0, 1, 18),   # Runtime -> RuntimeMonitoring
    (0, 2, 8),    # Runtime -> RuntimeAdaptation
    (0, 3, 6),    # Runtime -> RuntimeScheduling
    (0, 4, 5),    # Runtime -> RuntimePowerManagement
    (0, 5, 4),    # Runtime -> RuntimeDeploymentManagement
    (0, 6, 3),    # Runtime -> QoSDrivenControl
    (0, 7, 2),    # Runtime -> MetadataDrivenIntegration
    (0, 8, 2),    # Runtime -> RuntimeAutoscaling
    (0, 9, 1),    # Runtime -> Brownout
]

designtime_links = [
    (0, 10, 1),   # Runtime -> DesignTimeAnalysis
    (0, 11, 1),   # Runtime -> DesignTimeConstraints
    (0, 12, 1),   # Runtime -> PlacementOptimization
]

# Combine all links
all_links = runtime_links + designtime_links

# Create link colors - blue for runtime, orange for design-time
link_colors = ["rgba(31, 119, 180, 0.4)"] * len(runtime_links) + \
              ["rgba(255, 127, 14, 0.4)"] * len(designtime_links)

# Node colors - blue for source, blue shades for runtime approaches, orange shades for design-time
node_colors = ["#1f77b4"] + \
              ["#4292c6", "#6baed6", "#9ecae1", "#c6dbef", "#deebf7", 
               "#3182bd", "#6baed6", "#9ecae1", "#c6dbef"] + \
              ["#ff7f0e", "#ffbb78", "#fdd0a2"]

# Create the Sankey diagram
fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=25,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=nodes,
        color=node_colors,
        align="right",

    ),
    link=dict(
        source=[link[0] for link in all_links],
        target=[link[1] for link in all_links],
        value=[link[2] for link in all_links],
        color=link_colors,
    )
)])

fig.update_layout(
    font_size=18,
    height=700,
    width=1000,
    margin=dict(l=50, r=200, t=40, b=10)
)

fig.show()

# %%
# Export the Sankey diagram as SVG and PDF
# Note: This requires the kaleido package. Install with: pip install kaleido

try:
    # Export as SVG (best for LaTeX - scalable and editable)
    svg_path = 'rq1.1_sankey_diagram.svg'
    fig.write_image(svg_path, format='svg')
    print(f"✓ SVG exported to: {svg_path}")
    
    # Export as PDF (also good for LaTeX)
    pdf_path = 'rq1.1_sankey_diagram.pdf'
    fig.write_image(pdf_path, format='pdf')
    print(f"✓ PDF exported to: {pdf_path}")
    
    print("\nFor LaTeX, use:")
    print("\\usepackage{graphicx}")
    print(f"\\includegraphics[width=\\textwidth]{{{svg_path}}} % or {pdf_path}")
    
except Exception as e:
    print(f"Error exporting: {e}")
    print("\nTo export, install kaleido:")
    print("pip install kaleido")
# Out:
# ✓ SVG exported to: rq1.1_sankey_diagram.svg
# ✓ PDF exported to: rq1.1_sankey_diagram.pdf
#
# For LaTeX, use:
# \usepackage{graphicx}
# \includegraphics[width=\textwidth]{rq1.1_sankey_diagram.svg} % or rq1.1_sankey_diagram.pdf

# %% [markdown]
# ## Pie Charts - RQ1.1 Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# Create output directory if it doesn't exist
output_dir = 'output'
os.makedirs(output_dir, exist_ok=True)

# Chart 1: Lifecycle Stage Energy Awareness
data1 = {
    'Category': ['Runtime', 'Deployment', 'Design', 'Other\n(Development, Maintenance)'],
    'Count': [21, 9, 5, 3],  # Development (2) + Maintenance (1) = Other (3)
    'Percentage': [55.26, 23.68, 13.16, 7.89]
}
df1 = pd.DataFrame(data1)
colors1 = ['#6baed6', '#fdae6b', '#74c476', '#e0e0e0']  # Lighter colors

fig1, ax1 = plt.subplots(figsize=(10, 10))
wedges1, texts1, autotexts1 = ax1.pie(
    df1['Percentage'], 
    labels=df1['Category'],
    autopct='%1.1f%%',
    startangle=90,
    colors=colors1,
    textprops={'fontsize': 20, 'fontweight': 'bold'},
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)
plt.tight_layout(pad=2.0)
file_name = 'rq1.1.p1_pie'
fig1.savefig(os.path.join(output_dir, file_name + '.png'), dpi=300)
fig1.savefig(os.path.join(output_dir, file_name + '.pdf'))
plt.show()
print(f"Chart 1 saved to: {output_dir}/{file_name}.png and .pdf")
# Chart 2: Energy Integration Point
data2 = {
    'Category': ['Runtime', 'Design', 'Deployment', 'Other\n(Analysis, Configuration)'],
    'Count': [19, 4, 3, 3],  # Analysis (1) + Configuration (1) + Development (1) = Other (3)
    'Percentage': [65.52, 13.79, 10.34, 10.35]
}
df2 = pd.DataFrame(data2)
colors2 = ['#6baed6', '#74c476', '#fdae6b', '#e0e0e0']  # Lighter colors

fig2, ax2 = plt.subplots(figsize=(10, 10))
wedges2, texts2, autotexts2 = ax2.pie(
    df2['Percentage'],
    labels=df2['Category'],
    autopct='%1.1f%%',
    startangle=90,
    colors=colors2,
    textprops={'fontsize': 20, 'fontweight': 'bold'},
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)
plt.tight_layout(pad=2.0)
file_name = 'rq1.1.p2_pie'
fig2.savefig(os.path.join(output_dir, file_name + '.png'), dpi=300)
fig2.savefig(os.path.join(output_dir, file_name + '.pdf'))
plt.show()
print(f"Chart 2 saved to: {output_dir}/{file_name}.png and .pdf")

# Chart 3: Integration Approach
data3 = {
    'Category': ['RuntimeMonitoring', 'RuntimeAdaptation', 'RuntimeScheduling', 
                 'RuntimePowerManagement', 'Other\n(RuntimeDeployment, QoS, ...)'],
    'Count': [18, 8, 6, 5, 8],  # Combined all items with count <= 2
    'Percentage': [34.62, 15.38, 11.54, 9.62, 15.38]
}
df3 = pd.DataFrame(data3)
colors3 = ['#6baed6', '#9ecae1', '#c6dbef', '#deebf7', '#e0e0e0']  # Lighter shades of blue + gray

fig3, ax3 = plt.subplots(figsize=(10, 10))
wedges3, texts3, autotexts3 = ax3.pie(
    df3['Percentage'],
    labels=df3['Category'],
    autopct='%1.1f%%',
    startangle=90,
    colors=colors3,
    textprops={'fontsize': 14, 'fontweight': 'bold'},
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)
plt.tight_layout(pad=2.0)
file_name = 'rq1.1.p3_pie'
fig3.savefig(os.path.join(output_dir, file_name + '.png'), dpi=300)
fig3.savefig(os.path.join(output_dir, file_name + '.pdf'))
plt.show()
print(f"Chart 3 saved to: {output_dir}/{file_name}.png and .pdf")

# Print breakdown of "Other" categories
print("\n=== Other Categories Breakdown ===\n")
print("Chart 1 - Lifecycle Stage Energy Awareness (Other):")
print("  • Development: 2 (5.26%)")
print("  • Maintenance: 1 (2.63%)")
print("  Total: 3 (7.89%)\n")

print("Chart 2 - Energy Integration Point (Other):")
print("  • Analysis: 1 (3.45%)")
print("  • Configuration: 1 (3.45%)")
print("  • Development: 1 (3.45%)")
print("  Total: 3 (10.35%)\n")

print("Chart 3 - Integration Approach (Other):")
print("  • RuntimeDeploymentManagement: 2 (3.85%)")
print("  • QoSDrivenControl: 2 (3.85%)")
print("  • MetadataDrivenIntegration: 1 (1.92%)")
print("  • RuntimeAutoscaling: 1 (1.92%)")
print("  • Brownout: 1 (1.92%)")
print("  • DesignTimeAnalysis: 1 (1.92%)")
print("  Total: 8 (15.38%)")
# Out:
# Chart 1 saved to: output/rq1.1.p1_pie.png and .pdf
# Chart 2 saved to: output/rq1.1.p2_pie.png and .pdf
# Chart 3 saved to: output/rq1.1.p3_pie.png and .pdf
#
# === Other Categories Breakdown ===
#
# Chart 1 - Lifecycle Stage Energy Awareness (Other):
#   • Development: 2 (5.26%)
#   • Maintenance: 1 (2.63%)
#   Total: 3 (7.89%)
#
# Chart 2 - Energy Integration Point (Other):
#   • Analysis: 1 (3.45%)
#   • Configuration: 1 (3.45%)
#   • Development: 1 (3.45%)
#   Total: 3 (10.35%)
#
# Chart 3 - Integration Approach (Other):
#   • RuntimeDeploymentManagement: 2 (3.85%)
#   • QoSDrivenControl: 2 (3.85%)
#   • MetadataDrivenIntegration: 1 (1.92%)
#   • RuntimeAutoscaling: 1 (1.92%)
#   • Brownout: 1 (1.92%)
#   • DesignTimeAnalysis: 1 (1.92%)
#   Total: 8 (15.38%)

# %%
# Three Independent Horizontal Bar Charts for RQ1.1 Parameters
import numpy as np

# Prepare data for grouped bar chart
categories_p1 = ['Runtime', 'Deployment', 'Design', 'Other']
values_p1 = [55.26, 23.68, 13.16, 7.89]

categories_p2 = ['Runtime', 'Design', 'Deployment', 'Other']
values_p2 = [65.52, 13.79, 10.34, 10.35]

categories_p3 = ['RuntimeMonitoring', 'RuntimeAdaptation', 'RuntimeScheduling', 
                 'RuntimePowerMgmt', 'Other']
values_p3 = [34.62, 15.38, 11.54, 9.62, 15.38]

# Color schemes
colors_p1 = ['#6baed6', '#fdae6b', '#74c476', '#e0e0e0']
colors_p2 = ['#6baed6', '#74c476', '#fdae6b', '#e0e0e0']
colors_p3 = ['#6baed6', '#9ecae1', '#c6dbef', '#deebf7', '#e0e0e0']

# Chart 1: Lifecycle Stage Energy Awareness (P1)
fig1, ax1 = plt.subplots(figsize=(5, 3))
y_pos_p1 = np.arange(len(categories_p1))
bars1 = ax1.barh(y_pos_p1, values_p1, color=colors_p1, edgecolor='white', linewidth=1.5)
ax1.set_yticks(y_pos_p1)
ax1.set_yticklabels(categories_p1, fontsize=9, fontweight='bold')
ax1.set_xlabel('Percentage (%)', fontsize=9, fontweight='bold')
ax1.set_xlim(0, 70)
ax1.grid(axis='x', alpha=0.3, linestyle='--')
ax1.set_axisbelow(True)
# Add value labels
for i, (bar, val) in enumerate(zip(bars1, values_p1)):
    ax1.text(val + 1.5, i, f'{val:.1f}%', va='center', fontsize=8, fontweight='bold')
plt.tight_layout()
file_name_p1 = 'rq1.1_p1_horizontal'
fig1.savefig(os.path.join(output_dir, file_name_p1 + '.png'), dpi=300, bbox_inches='tight')
fig1.savefig(os.path.join(output_dir, file_name_p1 + '.pdf'), bbox_inches='tight')
plt.show()
print(f"P1 chart saved to: {output_dir}/{file_name_p1}.png and .pdf")

# Chart 2: Energy Integration Point (P2)
fig2, ax2 = plt.subplots(figsize=(5, 3))
y_pos_p2 = np.arange(len(categories_p2))
bars2 = ax2.barh(y_pos_p2, values_p2, color=colors_p2, edgecolor='white', linewidth=1.5)
ax2.set_yticks(y_pos_p2)
ax2.set_yticklabels(categories_p2, fontsize=9, fontweight='bold')
ax2.set_xlabel('Percentage (%)', fontsize=9, fontweight='bold')
ax2.set_xlim(0, 70)
ax2.grid(axis='x', alpha=0.3, linestyle='--')
ax2.set_axisbelow(True)
# Add value labels
for i, (bar, val) in enumerate(zip(bars2, values_p2)):
    ax2.text(val + 1.5, i, f'{val:.1f}%', va='center', fontsize=8, fontweight='bold')
plt.tight_layout()
file_name_p2 = 'rq1.1_p2_horizontal'
fig2.savefig(os.path.join(output_dir, file_name_p2 + '.png'), dpi=300, bbox_inches='tight')
fig2.savefig(os.path.join(output_dir, file_name_p2 + '.pdf'), bbox_inches='tight')
plt.show()
print(f"P2 chart saved to: {output_dir}/{file_name_p2}.png and .pdf")

# Chart 3: Integration Approach (P3)
fig3, ax3 = plt.subplots(figsize=(5, 3.5))
y_pos_p3 = np.arange(len(categories_p3))
bars3 = ax3.barh(y_pos_p3, values_p3, color=colors_p3, edgecolor='white', linewidth=1.5)
ax3.set_yticks(y_pos_p3)
ax3.set_yticklabels(categories_p3, fontsize=9, fontweight='bold')
ax3.set_xlabel('Percentage (%)', fontsize=9, fontweight='bold')
ax3.set_xlim(0, 40)
ax3.grid(axis='x', alpha=0.3, linestyle='--')
ax3.set_axisbelow(True)
# Add value labels
for i, (bar, val) in enumerate(zip(bars3, values_p3)):
    ax3.text(val + 0.8, i, f'{val:.1f}%', va='center', fontsize=8, fontweight='bold')
plt.tight_layout()
file_name_p3 = 'rq1.1_p3_horizontal'
fig3.savefig(os.path.join(output_dir, file_name_p3 + '.png'), dpi=300, bbox_inches='tight')
fig3.savefig(os.path.join(output_dir, file_name_p3 + '.pdf'), bbox_inches='tight')
plt.show()
print(f"P3 chart saved to: {output_dir}/{file_name_p3}.png and .pdf")

print("\n✓ All three charts saved as separate files - ready for horizontal layout in your document!")
# Out:
# P1 chart saved to: output/rq1.1_p1_horizontal.png and .pdf
# P2 chart saved to: output/rq1.1_p2_horizontal.png and .pdf
# P3 chart saved to: output/rq1.1_p3_horizontal.png and .pdf
#
# ✓ All three charts saved as separate files - ready for horizontal layout in your document!
